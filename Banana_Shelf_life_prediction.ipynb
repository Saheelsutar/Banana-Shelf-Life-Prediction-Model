# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip '/content/drive/MyDrive/banana_dataset.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Banana Ripeness Classification Dataset/train/rotten/musa-acuminata-rotten-8860f059-2653-11ec-bfdf-d8c4975e38aa_jpg.rf.973ca296d6529258c32f2e860f20ebb2.jpg
#   inflating: Banana Ripeness Classification Dataset/train/rotten/musa-acuminata-rotten-886553f8-2653-11ec-a0ca-d8c4975e38aa_jpg.rf.55777c63de172794863d47816ebb5219.jpg
#   inflating: Banana Ripeness Classification Dataset/train/rotten/musa-acuminata-rotten-886553f8-2653-11ec-a0ca-d8c4975e38aa_jpg.rf.ad8521768dfe4e51cd8ee471a979b440.jpg
#   inflating: Banana Ripeness Classification Dataset/train/rotten/musa-acuminata-rotten-886553f8-2653-11ec-a0ca-d8c4975e38aa_jpg.rf.feed0edb71d10358a4b41939ff544c81.jpg
#   inflating: Banana Ripeness Classification Dataset/train/rotten/musa-acuminata-rotten-8866be06-2653-11ec-9d14-d8c4975e38aa_jpg.rf.532ce5425f289dd5f8be244b9b4627e9.jpg
# ...

# %% [markdown]
# ## Rename the image filename and create csv

# %%
#creating csv for training dataset

import os
import pandas as pd

train_dir='/content/Banana Ripeness Classification Dataset/train'
classes=['overripe','ripe','rotten','unripe']

data=[]

for cls in classes:
  class_path=os.path.join(train_dir,cls)
  images=sorted(os.listdir(class_path))
  for i,img_name in enumerate(images,start=1):
    ext=os.path.splitext(img_name)[1]
    new_filename=f"img-{i}_{cls}{ext}"
    new_path=os.path.join(class_path,new_filename)
    old_path=os.path.join(class_path,img_name)
    os.rename(old_path,new_path)
    data.append(
        {
            "filename":new_filename,
            "label":cls,
            "path":new_path
        }

    )

df=pd.DataFrame(data)
csv_path=os.path.join(train_dir,'train.csv')
df.to_csv(csv_path,index=False)
print("CSV created successfully!")
# Out:
# CSV created successfully!

# %%
df.head()
# Out:
#              filename     label  \
# 0  img-1_overripe.jpg  overripe
# 1  img-2_overripe.jpg  overripe
# 2  img-3_overripe.jpg  overripe
# 3  img-4_overripe.jpg  overripe
# 4  img-5_overripe.jpg  overripe
#
#                                                 path
# 0  /content/Banana Ripeness Classification Datase...
# 1  /content/Banana Ripeness Classification Datase...
# 2  /content/Banana Ripeness Classification Datase...
# 3  /content/Banana Ripeness Classification Datase...
# 4  /content/Banana Ripeness Classification Datase...

# %%
#creating csv for testing dataset
import os
import pandas as pd

test_dir='/content/Banana Ripeness Classification Dataset/test'
classes=['overripe','ripe','rotten','unripe']

data=[]

for cls in classes:
  class_path=os.path.join(test_dir,cls)
  images=sorted(os.listdir(class_path))
  for i,img_name in enumerate(images,start=1):
    ext=os.path.splitext(img_name)[1]
    new_filename=f"img-{i}_{cls}{ext}"
    new_path=os.path.join(class_path,new_filename)
    old_path=os.path.join(class_path,img_name)
    os.rename(old_path,new_path)
    data.append(
        {
            "filename":new_filename,
            "label":cls,
            "path":new_path
        }

    )

df=pd.DataFrame(data)
csv_path=os.path.join(test_dir,'test.csv')
df.to_csv(csv_path,index=False)
print("CSV created successfully!")
# Out:
# CSV created successfully!

# %%
#creating csv for validation dataset
import os
import pandas as pd

valid_dir='/content/Banana Ripeness Classification Dataset/valid'
classes=['overripe','ripe','rotten','unripe']

data=[]

for cls in classes:
  class_path=os.path.join(valid_dir,cls)
  images=sorted(os.listdir(class_path))
  for i,img_name in enumerate(images,start=1):
    ext=os.path.splitext(img_name)[1]
    new_filename=f"img-{i}_{cls}{ext}"
    new_path=os.path.join(class_path,new_filename)
    old_path=os.path.join(class_path,img_name)
    os.rename(old_path,new_path)
    data.append(
        {
            "filename":new_filename,
            "label":cls,
            "path":new_path
        }

    )

df=pd.DataFrame(data)
csv_path=os.path.join(valid_dir,'valid.csv')
df.to_csv(csv_path,index=False)
print("CSV created successfully!")
# Out:
# CSV created successfully!

# %%
# %cd /content

# !zip -r banana_final_dataset.zip "Banana Ripeness Classification Dataset"
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: Banana Ripeness Classification Dataset/train/rotten/img-648_rotten.jpg (deflated 6%)
#   adding: Banana Ripeness Classification Dataset/train/rotten/img-162_rotten.jpg (deflated 2%)
#   adding: Banana Ripeness Classification Dataset/train/rotten/img-3800_rotten.jpg (deflated 1%)
#   adding: Banana Ripeness Classification Dataset/train/rotten/img-3566_rotten.jpg (deflated 1%)
#   adding: Banana Ripeness Classification Dataset/train/rotten/img-3970_rotten.jpg (deflated 2%)
#   adding: Banana Ripeness Classification Dataset/train/rotten/img-2743_rotten.jpg (deflated 1%)
#   adding: Banana Ripeness Classification Dataset/train/rotten/img-133_rotten.jpg (deflated 1%)
#   adding: Banana Ripeness Classification Dataset/train/rotten/img-3556_rotten.jpg (deflated 1%)
#   adding: Banana Ripeness Classification Dataset/train/rotten/img-3402_rotten.jpg (deflated 1%)
# ...

# %%
# !unzip '/content/drive/MyDrive/banana_final_dataset.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Banana Ripeness Classification Dataset/train/rotten/img-648_rotten.jpg
#   inflating: Banana Ripeness Classification Dataset/train/rotten/img-162_rotten.jpg
#   inflating: Banana Ripeness Classification Dataset/train/rotten/img-3800_rotten.jpg
#   inflating: Banana Ripeness Classification Dataset/train/rotten/img-3566_rotten.jpg
#   inflating: Banana Ripeness Classification Dataset/train/rotten/img-3970_rotten.jpg
#   inflating: Banana Ripeness Classification Dataset/train/rotten/img-2743_rotten.jpg
#   inflating: Banana Ripeness Classification Dataset/train/rotten/img-133_rotten.jpg
#   inflating: Banana Ripeness Classification Dataset/train/rotten/img-3556_rotten.jpg
#   inflating: Banana Ripeness Classification Dataset/train/rotten/img-3402_rotten.jpg
#   inflating: Banana Ripeness Classification Dataset/train/rotten/img-2068_rotten.jpg
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
csv_path='/content/Banana Ripeness Classification Dataset/train/train.csv'
df=pd.read_csv(csv_path)

plt.figure(figsize=(20,4))
for i,row in enumerate(df.sample(5).itertuples(),start=1):
  img=Image.open(row.path)
  plt.subplot(1,5,i)
  wt,ht=img.size
  plt.imshow(img)
  plt.axis('off')
  plt.title(f"h:{ht},w:{wt} ; {row.label}")

# %%
import random
train_df=pd.read_csv('/content/Banana Ripeness Classification Dataset/train/train.csv')
test_df=pd.read_csv('/content/Banana Ripeness Classification Dataset/test/test.csv')
valid_df=pd.read_csv('/content/Banana Ripeness Classification Dataset/valid/valid.csv')

# %% [markdown]
# ## Load dataset batch  wise

# %%
# !pip install tensorflow

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet  import preprocess_input
train_datagen=ImageDataGenerator(
    preprocessing_function=preprocess_input,
    #Applying data augmentation
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True,
    brightness_range=[0.8,1.2]
)
train_generator=train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='path',
    y_col='label',
    target_size=(224,224),#resize
    batch_size=152,
    class_mode='categorical'
)
# Out:
# Found 11793 validated image filenames belonging to 4 classes.

# %%
valid_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

valid_generator = valid_datagen.flow_from_dataframe(
    dataframe=valid_df,
    x_col='path',
    y_col='label',
    target_size=(224,224),
    batch_size=152,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 1123 validated image filenames belonging to 4 classes.

# %%
test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='path',
    y_col='label',
    target_size=(224,224),
    batch_size=152,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 562 validated image filenames belonging to 4 classes.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense,GlobalAveragePooling2D,Dropout
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Model

base_model = EfficientNetB0(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

# Freeze(weights are not updated of EfficientNet layers)
base_model.trainable = False
#customise layers added
x = base_model.output

x = GlobalAveragePooling2D()(x)

x = Dense(128, activation='relu')(x)

x = Dropout(0.3)(x)# to reduce dependency , random 30% subset of the 128 neurons is deactivated

output = Dense(4, activation='softmax')(x)

model = Model(
    inputs=base_model.input,
    outputs=output
)
# Out:
# ...
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(
    train_generator,
    validation_data=valid_generator,
    epochs=10
)
# Out:
# Epoch 1/10
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 245s 3s/step - accuracy: 0.7046 - loss: 0.8442 - val_accuracy: 0.9047 - val_loss: 0.4483
# Epoch 2/10
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 175s 2s/step - accuracy: 0.8933 - loss: 0.3662 - val_accuracy: 0.9466 - val_loss: 0.2532
# Epoch 3/10
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 172s 2s/step - accuracy: 0.9202 - loss: 0.2554 - val_accuracy: 0.9510 - val_loss: 0.1825
# Epoch 4/10
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 170s 2s/step - accuracy: 0.9286 - loss: 0.2160 - val_accuracy: 0.9573 - val_loss: 0.1542
# Epoch 5/10
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 171s 2s/step - accuracy: 0.9417 - loss: 0.1871 - val_accuracy: 0.9617 - val_loss: 0.1377
# Epoch 6/10
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 171s 2s/step - accuracy: 0.9444 - loss: 0.1682 - val_accuracy: 0.9644 - val_loss: 0.1229
# Epoch 7/10
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 171s 2s/step - accuracy: 0.9484 - loss: 0.1569 - val_accuracy: 0.9679 - val_loss: 0.1154
# Epoch 8/10
# ...

# %%
test_loss, test_acc = model.evaluate(test_generator)

print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 16s 5s/step - accuracy: 0.9626 - loss: 0.1080
# Test Accuracy: 0.9626

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

predictions = model.predict(test_generator)

y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

print(classification_report(
    y_true,
    y_pred,
    target_names=list(test_generator.class_indices.keys())
))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step
#               precision    recall  f1-score   support
#
#     overripe       0.96      0.91      0.94       113
#         ripe       0.93      0.98      0.95       154
#       rotten       0.98      0.96      0.97       185
#       unripe       0.98      1.00      0.99       110
#
#     accuracy                           0.96       562
#    macro avg       0.96      0.96      0.96       562
# weighted avg       0.96      0.96      0.96       562

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8,6))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    xticklabels=list(test_generator.class_indices.keys()),
    yticklabels=list(test_generator.class_indices.keys())
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
model.save('banana_shelf_life_prediction.keras')

# %%
from tensorflow.keras.models import load_model
model=load_model('/content/banana_shelf_life_prediction.keras')

# %%
print(train_generator.class_indices)
# Out:
# {'overripe': 0, 'ripe': 1, 'rotten': 2, 'unripe': 3}

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.efficientnet import preprocess_input

class_names=['overripe','ripe','rotten','unripe']
def preprocess_img(img_path):
  img=image.load_img(
      img_path,
      target_size=(224,224)
  )
  img_array=image.img_to_array(img)
  img_array=np.expand_dims(img_array,axis=0)
  img_array=preprocess_input(img_array)
  return img_array

# %%
shelf_life = {
    "unripe": "6-9 days",
    "ripe": "3-5 days",
    "overripe": "1-2 days",
    "rotten": "0 days"
}

img_path='inp.jpeg'
pred=model.predict(preprocess_img(img_path))
predicted_class=class_names[np.argmax(pred)]


print(
    "Estimated Shelf Life:",
    shelf_life[predicted_class]
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step
# Estimated Shelf Life: 3-5 days
